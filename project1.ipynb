# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'],
    'Sales': [15000, 18000, 12000, 22000, 27000, 30000],
    'Profit': [4000, 5000, 3000, 7000, 9000, 10000]
}

df = pd.DataFrame(data)

# %%
print("📄 Sales Dataset:")
display(df)
# Out:
# 📄 Sales Dataset:
#   Month  Sales  Profit
# 0   Jan  15000    4000
# 1   Feb  18000    5000
# 2   Mar  12000    3000
# 3   Apr  22000    7000
# 4   May  27000    9000
# 5   Jun  30000   10000

# %%
plt.figure(figsize=(8,5))
plt.plot(df['Month'], df['Sales'], color='royalblue', marker='o', label='Sales')
plt.plot(df['Month'], df['Profit'], color='seagreen', marker='s', label='Profit')
plt.title('Monthly Sales & Profit Trend')
plt.xlabel('Month')
plt.ylabel('Amount (₹)')
plt.legend()
plt.grid(True)
plt.show()

# %%
best_month = df.loc[df['Sales'].idxmax(), 'Month']
print(f"🔥 Highest Sales Month: {best_month}")
# Out:
# 🔥 Highest Sales Month: Jun

# %%
average_profit = df['Profit'].mean()
print(f"💰 Average Monthly Profit: ₹{average_profit:.2f}")
# Out:
# 💰 Average Monthly Profit: ₹6333.33
